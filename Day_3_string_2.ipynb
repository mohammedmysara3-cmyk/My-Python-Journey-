# %% [markdown]
# Python Basics - Day 3
#
# Countine working with string.

# %%
a = "    ##check this##    "

# %%
a[6:16] #this called indexing
# Out:
# 'check this'

# %% [markdown]
# Indexing
#
# Calling single part or multible parts of a string,
#
# you can also extract this parts on another variable
#
# this can be usefull later.

# %%
a.strip() #clearing the string from leading\trailing spaces
# Out:
# '##check this##'

# %%
a.strip (" #") #you can use it to clear any charcter from the leading\trailing slices
# Out:
# 'check this'

# %%
a.index ("c")
# Out:
# 6

# %%
a.upper () #convert all letters to upper case
# Out:
# '    ##CHECK THIS##    '

# %%
a.lower () #convert all letters to lower case
# Out:
# '    ##check this##    '

# %%
a.title () #convert first letter of each word to upper case
# Out:
# '    ##Check This##    '

# %%
a.split () #split the string into list of words
# Out:
# ['##check', 'this##']

# %%
type(a.split ()) #check the type of the output
# Out:
# list

# %%
b = "i love python"
b.split (" ", 1) #split the string into list of words at the first space only
# Out:
# ['i', 'love python']

# %%
b.count ("o") #count how many times a specific character appears in the string
# Out:
# 2

# %%
b.count ("love") #count how many times a specific substring appears in the string
# Out:
# 1

# %%
b.find ("y") #find the first index of a specific character
# Out:
# 8

# %%
x = "one two three one two"
x.replace ("one", "1") #replace all occurrences of a substring with another substring
# Out:
# '1 two three 1 two'

# %%
x.replace ("one" , "1", 1) #replace only the first occurrence of a substring with another substring
# Out:
# '1 two three one two'

# %%
z = ["apple", "banana" , "cherry"]
", ".join (z) #join the list elements into a single string with a specific separator
# Out:
# 'apple, banana, cherry'

# %%
type(", ".join (z))
# Out:
# str

# %%
N = "green"
A = "yellow"
Z = "red"
print ("apples are %s, bananas are %s, cherries are %s" % (N, A, Z))
#This is an old-style string formatting method using the % operator.
# Out:
# apples are green, bananas are yellow, cherries are red

# %% [markdown]
# till further notice🐍
