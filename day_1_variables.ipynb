# %% [markdown]
# # Python Basics - Day 1
# تعلم المتغيرات و انواع البيانات في لغه بايثون

# %%
# Variables
name = "mohammed"
age = 24
hight = 171.6
is_engineer = True

# %%
print (name)
print (age)
print (hight)
print (is_engineer)
# Out:
# mohammed
# 24
# 171.6
# True

# %%
# Defining data types
type (name)
# Out:
# str

# %%
type (age)
# Out:
# int

# %%
type (hight)
# Out:
# float

# %%
type (is_engineer)
# Out:
# bool

# %%
print (name, age)
# Out:
# mohammed 24

# %% [markdown]
# HELP FUNCTION
#
# A dectionary full of usefull guide throw every problem you can face in the process, examples and difnition  are provided.

# %% [markdown]
# till further notice.🐍
