# %% [markdown]
# Python Basics - Day 2
#
# working with strings (type: str)

# %%
print ("hello my name is mohammed \
and i work as a site engineer") #notice (\) : ignoring what comes after wich is new line.
# Out:
# hello my name is mohammed and i work as a site engineer

# %%
print ("sky is blue \\ ")
# Out:
# sky is blue \

# %%
print ("sky is blue \\\ ")
# Out:
# sky is blue \\

# %%
print ("sky is blue \n and the grass is green") # (\n) : new line.
# Out:
# sky is blue
#  and the grass is green

# %%
#-------------------------------------------------------------------

# %%
print ("123456\rasdf") # Currige return
# Out:
# asdf56

# %% [markdown]
# #User-Defined Inputs
#
# run :
#
# name = input ("Enter your name: ")
#
#
# age = input ("Enter your age: ")
#
#
# work = input ("what are you currantly do for living?")
#
#
# print("Hello {} , can you tell more about your job : ({}), i heared also you're {} years old, good for you!!".format(name, work, age))

# %%
string_1 = "you used to \
connect multiple line string \
useing this method"

# %%
string_2 = '''now with this trible qutation marks 
you free to go as many lines as you need
with out worring about (\) how does it sound?'''

# %%
print (string_1)
print (string_2)
# Out:
# we used to connect multiple line string useing this method
# now with this trible qutation marks
# we free to go as many lines as you need
# with out worring about (\) how does it sound?

# %%
# Quick tip
print ("you can also do 'this' if you need to", ',you can try "this" also')
# Out:
# you can also do 'this' if you need to ,you can try "this" also

# %% [markdown]
# till further notice
